# %% [markdown]
# <a href="https://colab.research.google.com/github/jhamilton1975/AutoAgent/blob/main/Business_Statistics_E_news.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## CRITERIA

# %%
### PROBLEM DEFINITION, QUESTIONS TO BE ANSWERED
##.                                                        BACKGROUND INFORMATION TO THE PROJECT:
#.  The design team of the company has researched and created a new landing page that has a new outline & more relevant content shown compared to the old page.
#   In order to test the effectiveness of the new landing page in gathering new subscribers, the Data Science team conducted an experiment by randomly selecting 100 users and dividing them equally
#   into two groups. The existing landing page was served to the first group (control group) and the new landing page to the second group (treatment group).
#.  Data regarding the interaction of users in both groups with the two versions of the landing page was collected. Being a data scientist in E-news Express,
#.  you have been asked to explore the data and perform a statistical analysis (at a significance level of 5%) to determine the effectiveness of the new landing page in
#.  gathering new subscribers for the news portal by answering the following questions:

##                                                          QUESTIONS:
#. (1) Do the users spend more time on the new landing page than on the existing landing page?
#. (2) Is the conversion rate (the proportion of users who visit the landing page and get converted) for the new page greater than the conversion rate for the old page?
#  (3) Does the converted status depend on the preferred language?
#  (4) Is the time spent on the new page the same for the different language users?

##.                                                         THE KEY POINTS IN THE PRESENTATION SHOULD BE:
#.  Business Overview of the problem and solution approach
#.  Key findings and insights which can drive business decisions
#.  Business recommendations
#.  Focus on explaining the key takeaways in an easy-to-understand manner.
#.  The inclusion of the potential benefits of implementing the solution will give you the edge.

# %%
### DATA BACKGROUND AND CONTENTS

# %%
#INSTALL THE DEPENDENCIES
# !pip install numpy==1.25.2 pandas==1.5.3 matplotlib==3.7.1 seaborn==0.13.1 scipy==1.11.4 -q --user
# Out:
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
#IMPORT THE LIBRARIES
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Library to help with statistical analysis
import scipy.stats as stats

# %%
#LOADING THE DATA
data = pd.read_csv('abtest.csv')

# %%
#EXPLORATORY DATA ANALYSIS - Univariate and bivariate analysis

# %%
#view the first 10 rows of the dataset
data.head(10)
# Out:
#    user_id      group landing_page  time_spent_on_the_page converted  \
# 0   546592    control          old                    3.48        no
# 1   546468  treatment          new                    7.13       yes
# 2   546462  treatment          new                    4.40        no
# 3   546567    control          old                    3.02        no
# 4   546459  treatment          new                    4.75       yes
# 5   546558    control          old                    5.28       yes
# 6   546448  treatment          new                    5.25       yes
# 7   546581    control          old                    6.53       yes
# 8   546461  treatment          new                   10.71       yes
# 9   546548    control          old                    2.08        no
#
#   language_preferred
# 0            Spanish
# 1            English
# 2            Spanish
# 3             French
# 4            Spanish
# 5            English
# 6             French
# 7            Spanish
# ...

# %%
#view the last 10 rows of the dataset
data.tail(10)
# Out:
#     user_id      group landing_page  time_spent_on_the_page converted  \
# 90   546477  treatment          new                    5.40        no
# 91   546451  treatment          new                    8.47       yes
# 92   546566    control          old                    8.35        no
# 93   546474  treatment          new                    4.94        no
# 94   546550    control          old                    3.05        no
# 95   546446  treatment          new                    5.15        no
# 96   546544    control          old                    6.52       yes
# 97   546472  treatment          new                    7.07       yes
# 98   546481  treatment          new                    6.20       yes
# 99   546483  treatment          new                    5.86       yes
#
#    language_preferred
# 90             French
# 91            English
# 92             French
# 93             French
# 94            English
# 95            Spanish
# 96            English
# ...

# %%
#check the shape of the dataset
data.shape
# Out:
# (100, 6)

# %%
#check the dat types of the columns for the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 100 non-null    int64
#  1   group                   100 non-null    object
#  2   landing_page            100 non-null    object
#  3   time_spent_on_the_page  100 non-null    float64
#  4   converted               100 non-null    object
#  5   language_preferred      100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
#statistical summary for the numerical variables
data.describe(include='number')
# Out:
#              user_id  time_spent_on_the_page
# count     100.000000              100.000000
# mean   546517.000000                5.377800
# std        52.295779                2.378166
# min    546443.000000                0.190000
# 25%    546467.750000                3.880000
# 50%    546492.500000                5.415000
# 75%    546567.250000                7.022500
# max    546592.000000               10.710000

# %%
#statistical summary for the categorical variables
data.describe(include='object')
# Out:
#           group landing_page converted language_preferred
# count       100          100       100                100
# unique        2            2         2                  3
# top     control          old       yes            Spanish
# freq         50           50        54                 34

# %%
#check missing values
data.isnull().sum()
# Out:
# user_id                   0
# group                     0
# landing_page              0
# time_spent_on_the_page    0
# converted                 0
# language_preferred        0
# dtype: int64

# %%
#check for duplicates
data.duplicated().sum()   #total number of duplicates
#data.duplicated(subset=['user_id', 'group', 'landing_page', 'time_spent_on_the_page', 'converted', 'language_preferred']).sum()    #for each column
# Out:
# np.int64(0)

# %%
### UNIVARIATE ANALYSIS

# %%
#time spent on the page
sns.histplot(data=data,x='time_spent_on_the_page')
plt.show()
sns.boxplot(data=data,x='time_spent_on_the_page')
plt.show()

# %%
#group
data['group'].value_counts()
# Out:
# group
# control      50
# treatment    50
# Name: count, dtype: int64

# %%
sns.countplot(data=data,x='group')
plt.show()

# %%
#landing page
data['landing_page'].value_counts()
# Out:
# landing_page
# old    50
# new    50
# Name: count, dtype: int64

# %%
# complete the code to plot the countplot
sns.countplot(data=data,x='landing_page')
plt.show()

# %%
#converted
data['converted'].value_counts()
# Out:
# converted
# yes    54
# no     46
# Name: count, dtype: int64

# %%
# complete the code to plot the countplot
sns.countplot(data=data,x= 'converted')
plt.show()

# %%
#language preferred
data['language_preferred'].value_counts()
# Out:
# language_preferred
# Spanish    34
# French     34
# English    32
# Name: count, dtype: int64

# %%
# complete the code to plot the countplot
sns.countplot(data=data, x='language_preferred')
plt.show()

# %%
## BIVARIATE ANALYSIS

# %%
#landing page vs time spent on the page
plt.figure(figsize=(10,6))
sns.boxplot(data=data,x='landing_page',y='time_spent_on_the_page')
plt.show()

# %%
# conversion status vs time spent on the page
plt.figure(figsize=(9, 9))
sns.boxplot(data = data, x = 'converted', y = 'time_spent_on_the_page')
plt.show()

# %%
#language preferred vs time spent on the page
plt.figure(figsize=(9, 9))
sns.boxplot(data = data, x = 'language_preferred', y = 'time_spent_on_the_page')
plt.show()
